# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('/Users/duncanwan/Desktop/learning/Bitcoin/4hrs/BTC_combined_2504_08v4.csv')

df['bar_end'] = pd.to_datetime(df['bar_end'])

df = df.set_index('bar_end')

df = df.drop(columns=[c for c in df.columns if c.lower().startswith('unnamed')], errors='ignore')

df['funding_rate_&'] = df['funding_rate'] * 100

# %%
#query date

#top
dates = ['2025-05-22', '2025-05-23', '2025-07-09', '2025-07-10','2025-07-11','2025-07-14', '2025-08-13', '2025-08-14','2025-08-15']
sel = pd.concat([df.loc[d] for d in dates]).sort_index()

sel
# Out:
#                            spot_close      spot_vol  perp_close    perp_vol  \
# bar_end
# 2025-05-22 00:00:00+00:00   109643.99   7509.937825    109609.5   58886.898
# 2025-05-22 04:00:00+00:00   111780.84   9017.731680    111755.9   64755.016
# 2025-05-22 08:00:00+00:00   111045.45   7103.403380    111005.8   47573.709
# 2025-05-22 12:00:00+00:00   110981.97   4014.187880    110944.1   32748.467
# 2025-05-22 16:00:00+00:00   111290.86   6086.260180    111250.6   49945.987
# 2025-05-22 20:00:00+00:00   111188.00   3260.632700    111136.1   34534.378
# 2025-05-23 00:00:00+00:00   111696.21   2148.557310    111662.7   16509.476
# 2025-05-23 04:00:00+00:00   111100.01   2834.294820    111044.0   22959.440
# 2025-05-23 08:00:00+00:00   110715.42   3226.515000    110685.2   23761.569
# 2025-05-23 12:00:00+00:00   109076.35   4204.186340    109033.2   45137.260
# 2025-05-23 16:00:00+00:00   108940.00  13163.258080    108892.4  108855.124
# 2025-05-23 20:00:00+00:00   108716.07   4951.180810    108659.4   46212.629
# 2025-07-09 00:00:00+00:00   108922.98    604.799190    108873.1    6019.289
# 2025-07-09 04:00:00+00:00   108376.41    994.802260    108311.9   11601.542
# 2025-07-09 08:00:00+00:00   108714.39   1001.599150    108674.8    9998.912
# 2025-07-09 12:00:00+00:00   109058.27   1275.996160    109008.3    9544.375
# 2025-07-09 16:00:00+00:00   109071.32   4108.391310    109020.0   44231.698
# 2025-07-09 20:00:00+00:00   111750.00   6338.574550    111718.8   55843.017
# 2025-07-10 00:00:00+00:00   111233.99   3562.923070    111199.9   36615.187
# 2025-07-10 04:00:00+00:00   111074.51   1687.734660    111028.2   13062.149
# 2025-07-10 08:00:00+00:00   111230.00   1667.114130    111186.1   10503.767
# 2025-07-10 12:00:00+00:00   111019.99   1407.792970    110972.2   12366.984
# 2025-07-10 16:00:00+00:00   111408.40   2221.217370    111350.0   29486.905
# 2025-07-10 20:00:00+00:00   113301.81   7461.037691    113246.1   78710.069
# 2025-07-11 00:00:00+00:00   116010.00  10438.553844    115979.2   81440.339
# 2025-07-11 04:00:00+00:00   116881.70   4456.671301    116839.5   29918.240
# 2025-07-11 08:00:00+00:00   117526.88   7940.173377    117522.7   57156.787
# 2025-07-11 12:00:00+00:00   117821.91   4664.061610    117790.1   30866.366
# 2025-07-11 16:00:00+00:00   116902.59   4711.374080    116910.3   41834.893
# 2025-07-11 20:00:00+00:00   118108.81   2754.726470    118072.7   25630.995
# 2025-07-14 00:00:00+00:00   119086.64   1660.446830    119038.3   15256.519
# 2025-08-30 20:00:00+00:00  False         False         False     False
# 2025-08-31 00:00:00+00:00   True          True         False      True
# 2025-08-31 04:00:00+00:00  False         False         False     False
# 2025-08-31 08:00:00+00:00   True         False          True      True
# 2025-08-31 12:00:00+00:00  False         False         False     False
# 2025-08-31 16:00:00+00:00  False         False         False     False
# 2025-08-31 20:00:00+00:00  False         False         False     False

# %%
df.describe()
# Out:
#           spot_close      spot_vol     perp_close       perp_vol  \
# count     918.000000    918.000000     918.000000     918.000000
# mean   105207.274619   3070.852511  105164.178214   27420.127124
# std     11292.827907   2577.369705   11294.429905   23062.352976
# min     75073.330000    340.576630   75040.000000    3193.792000
# 25%    101187.857500   1501.129997  101140.425000   13221.130000
# 50%    107162.745000   2354.545400  107111.150000   20968.309500
# 75%    114304.057500   3749.411125  114249.375000   33112.052000
# max    123337.140000  27708.971460  123405.200000  284460.151000
#
#        funding_rate  funding_rate_&
# count    739.000000      739.000000
# mean       0.000054        0.005425
# std        0.000041        0.004104
# min       -0.000122       -0.012232
# 25%        0.000026        0.002622
# 50%        0.000053        0.005297
# 75%        0.000100        0.010000
# max        0.000100        0.010000

# %%
# pick window on each side: k=6 ≈ 1 day each side on 4h bars
k = 6
roll_max = df['perp_close'].rolling(2*k+1, center=True).max()
roll_min = df['perp_close'].rolling(2*k+1, center=True).min()
df['is_top']    = df['perp_close'].eq(roll_max)
df['is_bottom'] = df['perp_close'].eq(roll_min)

print("tops:", int(df['is_top'].sum()), "bottoms:", int(df['is_bottom'].sum()))

# quick plot with markers
import matplotlib.pyplot as plt
tops    = df.index[df['is_top']]
bottoms = df.index[df['is_bottom']]

fig, ax = plt.subplots(figsize=(12,5))
ax.plot(df.index, df['perp_close'], lw=1.2, color='tab:blue', label='Perp')

ax.vlines(tops,    ymin=df['perp_close'].min(), ymax=df['perp_close'].max(),
          colors='crimson', alpha=0.15, lw=1)
ax.vlines(bottoms, ymin=df['perp_close'].min(), ymax=df['perp_close'].max(),
          colors='green',   alpha=0.15, lw=1)

ax2 = ax.twinx()
ax2.step(df.index, df['funding_rate'], where='post', lw=1.0, color='tab:orange', label='Funding')

ax.set_title('4H price with centered tops/bottoms; funding step')
ax.legend(loc='upper left')
plt.show()
# Out:
# tops: 48 bottoms: 46

# %%
import numpy as np

sign_now  = np.sign(df['funding_rate'])
sign_prev = np.sign(df['funding_rate'].shift(1))

# flip if sign changes and neither side is exactly zero
df['flip'] = sign_now.ne(sign_prev) & sign_now.ne(0) & sign_prev.ne(0)

# optional: direction-specific flags
df['flip_pos2neg'] = (df['funding_rate'] < 0) & (df['funding_rate'].shift(1) > 0)
df['flip_neg2pos'] = (df['funding_rate'] > 0) & (df['funding_rate'].shift(1) < 0)

# plot flips on price
flips = df.index[df['flip']]

fig, ax = plt.subplots(figsize=(12,5))
ax.plot(df.index, df['perp_close'], lw=1.2, color='tab:blue')
ax.scatter(flips, df.loc[flips,'perp_close'], s=18, marker='^', color='black', label='Funding flip', zorder=3)

ax2 = ax.twinx()
ax2.step(df.index, df['funding_rate'], where='post', lw=1.0, color='tab:orange')

ax.set_title('Funding sign flips (▲) overlaid on price')
ax.legend(loc='upper left')
plt.show()

# %%
eps = 1e-8

f_now  = df['funding_rate']
f_prev = df['funding_rate'].shift(1)

# + → −
df['flip_pos2neg'] = (f_prev >  +eps) & (f_now <  -eps)

# − → +
df['flip_neg2pos'] = (f_prev <  -eps) & (f_now >  +eps)

# if you still want a combined flag:
df['flip_any'] = df['flip_pos2neg'] | df['flip_neg2pos']

p2n = df.index[df['flip_pos2neg']]
n2p = df.index[df['flip_neg2pos']]

ax.plot(df.index, df['perp_close'], lw=1.2, color='tab:blue')
ax.scatter(p2n, df.loc[p2n,'perp_close'], s=18, c='crimson', marker='v', label='+→−', zorder=3)
ax.scatter(n2p, df.loc[n2p,'perp_close'], s=18, c='limegreen', marker='^', label='−→+', zorder=3)
ax.legend(loc='upper left')

print("pos→neg:", int(df['flip_pos2neg'].sum()))
print("neg→pos:", int(df['flip_neg2pos'].sum()))
plt.show()
# Out:
# pos→neg: 19
# neg→pos: 19

# %%
import matplotlib.pyplot as plt
import numpy as np

eps = 1e-8
f_now  = df['funding_rate']
f_prev = df['funding_rate'].shift(1)

df['flip_pos2neg'] = (f_prev >  +eps) & (f_now <  -eps)
df['flip_neg2pos'] = (f_prev <  -eps) & (f_now >  +eps)
df['flip_any']     = df['flip_pos2neg'] | df['flip_neg2pos']

p2n = df.index[df['flip_pos2neg']]
n2p = df.index[df['flip_neg2pos']]

# ✅ create a fresh figure/axes here
fig, ax = plt.subplots(figsize=(12,5))

ax.plot(df.index, df['perp_close'], lw=1.2, color='tab:blue')
ax.scatter(p2n, df.loc[p2n,'perp_close'], s=18, c='crimson',   marker='v', label='+→−', zorder=3)
ax.scatter(n2p, df.loc[n2p,'perp_close'], s=18, c='limegreen', marker='^', label='−→+', zorder=3)
ax.legend(loc='upper left')
ax.set_title('Funding sign flips on price')

plt.tight_layout()
plt.show()

print("pos→neg:", int(df['flip_pos2neg'].sum()))
print("neg→pos:", int(df['flip_neg2pos'].sum()))
# Out:
# pos→neg: 19
# neg→pos: 19

# %%
#line chart
fig, ax = plt.subplots(figsize=(12,4))
ax.plot(df.index, df['funding_rate'], lw=1.0)
ax.set_title('Funding rate (per 8h) — time series')
ax.set_ylabel('Funding rate')
ax.grid(True, alpha=0.2)
plt.show()

# %%
#distibution chart

x = df['funding_rate'].dropna().values
p25, p50, p75 = np.percentile(x, [25,50,75])
mean = np.mean(x)

fig, ax = plt.subplots(figsize=(8,4))
ax.hist(x, bins=50, alpha=0.8)
ax.axvline(mean,  color='tab:blue',  linestyle='--', lw=1.2, label=f'mean {mean:.2e}')
ax.axvline(p50,   color='tab:orange',linestyle='--', lw=1.2, label=f'median {p50:.2e}')
ax.axvline(p25,   color='tab:green', linestyle=':',  lw=1.0, label=f'P25 {p25:.2e}')
ax.axvline(p75,   color='tab:red',   linestyle=':',  lw=1.0, label=f'P75 {p75:.2e}')
ax.set_title('Funding rate — distribution (all bars, no time)')
ax.set_xlabel('Funding rate')
ax.set_ylabel('Count')
ax.legend()
ax.grid(True, alpha=0.15)
plt.show()
